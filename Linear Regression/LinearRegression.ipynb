# %% [markdown]
# # Linear Regression Model
# Nandini Sah

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the dataset

# %%
data = pd.read_csv("CarPrice_Assignment.csv", index_col=0)
data.head()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
#
#             carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# car_ID                                                               ...
# 1       convertible        rwd          front       88.6      168.8  ...
# 2       convertible        rwd          front       88.6      168.8  ...
# 3         hatchback        rwd          front       94.5      171.2  ...
# 4             sedan        fwd          front       99.8      176.6  ...
# 5             sedan        4wd          front       99.4      176.6  ...
#
#         enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# car_ID
# 1              130        mpfi       3.47   2.68              9.0         111
# 2              130        mpfi       3.47   2.68              9.0         111
# 3              152        mpfi       2.68   3.47              9.0         154
# 4              109        mpfi       3.19   3.40             10.0         102
# 5              136        mpfi       3.19   3.40              8.0         115
#
#        peakrpm  citympg  highwaympg    price
# car_ID
# 1         5000       21          27  13495.0
# 2         5000       21          27  16500.0
# 3         5000       19          26  16500.0
# 4         5500       24          30  13950.0
# 5         5500       18          22  17450.0
#
# [5 rows x 25 columns]

# %%
# divided the columns into categorical and numerical ones

num_Cols = ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 
            'horsepower', 'peakrpm', 'citympg', 'highwaympg']

cat_cols = ['symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 
            'cylindernumber', 'fuelsystem']

# %%
# checking for no. of unique values in each categorical column

for col in cat_cols:
    print(f"{col}: {data[col].nunique()} unique values")
# Out:
# symboling: 6 unique values
# fueltype: 2 unique values
# aspiration: 2 unique values
# doornumber: 2 unique values
# carbody: 5 unique values
# drivewheel: 3 unique values
# enginelocation: 2 unique values
# enginetype: 7 unique values
# cylindernumber: 7 unique values
# fuelsystem: 8 unique values

# %%
# removing the categorical columns which have low variance

low_variance_cols = [col for col in cat_cols if data[col].value_counts(normalize=True).iloc[0] > 0.95]
print("Low variance categorical columns:", low_variance_cols)
# Out:
# Low variance categorical columns: ['enginelocation']

# %%
data = data.drop(columns=low_variance_cols)
data = data.drop(columns=['CarName'])
data
# Out:
#         symboling fueltype aspiration doornumber      carbody drivewheel  \
# car_ID
# 1               3      gas        std        two  convertible        rwd
# 2               3      gas        std        two  convertible        rwd
# 3               1      gas        std        two    hatchback        rwd
# 4               2      gas        std       four        sedan        fwd
# 5               2      gas        std       four        sedan        4wd
# ...           ...      ...        ...        ...          ...        ...
# 201            -1      gas        std       four        sedan        rwd
# 202            -1      gas      turbo       four        sedan        rwd
# 203            -1      gas        std       four        sedan        rwd
# 204            -1   diesel      turbo       four        sedan        rwd
# 205            -1      gas      turbo       four        sedan        rwd
#
#         wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# car_ID                                             ...
# 1            88.6      168.8      64.1       48.8  ...         130       mpfi
# 2            88.6      168.8      64.1       48.8  ...         130       mpfi
# 3            94.5      171.2      65.5       52.4  ...         152       mpfi
# 4            99.8      176.6      66.2       54.3  ...         109       mpfi
# 5            99.4      176.6      66.4       54.3  ...         136       mpfi
# ...           ...        ...       ...        ...  ...         ...        ...
# 201         109.1      188.8      68.9       55.5  ...         141       mpfi
# 202         109.1      188.8      68.8       55.5  ...         141       mpfi
# 203         109.1      188.8      68.9       55.5  ...         173       mpfi
# 204         109.1      188.8      68.9       55.5  ...         145        idi
# 205         109.1      188.8      68.9       55.5  ...         141       mpfi
#
#        boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# car_ID
# 1           3.47    2.68              9.0         111     5000       21
# 2           3.47    2.68              9.0         111     5000       21
# 3           2.68    3.47              9.0         154     5000       19
# 4           3.19    3.40             10.0         102     5500       24
# 5           3.19    3.40              8.0         115     5500       18
# ...          ...     ...              ...         ...      ...      ...
# 201         3.78    3.15              9.5         114     5400       23
# 202         3.78    3.15              8.7         160     5300       19
# 203         3.58    2.87              8.8         134     5500       18
# 204         3.01    3.40             23.0         106     4800       26
# 205         3.78    3.15              9.5         114     5400       19
#
#         highwaympg    price
# car_ID
# 1               27  13495.0
# 2               27  16500.0
# 3               26  16500.0
# 4               30  13950.0
# 5               22  17450.0
# ...            ...      ...
# 201             28  16845.0
# 202             25  19045.0
# 203             23  21485.0
# 204             27  22470.0
# 205             25  22625.0
#
# [205 rows x 23 columns]

# %%
existing_cols = [item for item in cat_cols if item not in low_variance_cols]
data = pd.get_dummies(data, columns=existing_cols, drop_first=True)  # One-hot encode


# removing the columns with low correlation with the target variable
correlations = data.drop(columns=num_Cols).corr()['price'].abs().sort_values(ascending=False)
low_correlation_cats = correlations[correlations < 0.05].index.tolist()

print("Categorical columns with low correlation to price:", low_correlation_cats)
# Out:
# Categorical columns with low correlation to price: ['carbody_wagon', 'enginetype_l', 'doornumber_two', 'fuelsystem_spfi', 'fuelsystem_4bbl', 'enginetype_ohcf', 'enginetype_rotor', 'cylindernumber_two', 'fuelsystem_mfi']

# %%
data = data.drop(low_correlation_cats, axis=1)
data
# Out:
#         wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# car_ID
# 1            88.6      168.8      64.1       48.8        2548         130
# 2            88.6      168.8      64.1       48.8        2548         130
# 3            94.5      171.2      65.5       52.4        2823         152
# 4            99.8      176.6      66.2       54.3        2337         109
# 5            99.4      176.6      66.4       54.3        2824         136
# ...           ...        ...       ...        ...         ...         ...
# 201         109.1      188.8      68.9       55.5        2952         141
# 202         109.1      188.8      68.8       55.5        3049         141
# 203         109.1      188.8      68.9       55.5        3012         173
# 204         109.1      188.8      68.9       55.5        3217         145
# 205         109.1      188.8      68.9       55.5        3062         141
#
#         boreratio  stroke  compressionratio  horsepower  ...  enginetype_ohcv  \
# car_ID                                                   ...
# 1            3.47    2.68               9.0         111  ...            False
# 2            3.47    2.68               9.0         111  ...            False
# 3            2.68    3.47               9.0         154  ...             True
# 4            3.19    3.40              10.0         102  ...            False
# 5            3.19    3.40               8.0         115  ...            False
# ...           ...     ...               ...         ...  ...              ...
# 201          3.78    3.15               9.5         114  ...            False
# 202          3.78    3.15               8.7         160  ...            False
# 203          3.58    2.87               8.8         134  ...             True
# 204          3.01    3.40              23.0         106  ...            False
# 205          3.78    3.15               9.5         114  ...            False
#
#         cylindernumber_five  cylindernumber_four  cylindernumber_six  \
# car_ID
# 1                     False                 True               False
# 2                     False                 True               False
# 3                     False                False                True
# 4                     False                 True               False
# 5                      True                False               False
# ...                     ...                  ...                 ...
# 201                   False                 True               False
# 202                   False                 True               False
# 203                   False                False                True
# 204                   False                False                True
# 205                   False                 True               False
#
#         cylindernumber_three  cylindernumber_twelve  fuelsystem_2bbl  \
# car_ID
# 1                      False                  False            False
# 2                      False                  False            False
# 3                      False                  False            False
# 4                      False                  False            False
# 5                      False                  False            False
# ...                      ...                    ...              ...
# 201                    False                  False            False
# 202                    False                  False            False
# 203                    False                  False            False
# 204                    False                  False            False
# 205                    False                  False            False
#
#         fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi
# car_ID
# 1                False             True            False
# 2                False             True            False
# 3                False             True            False
# 4                False             True            False
# 5                False             True            False
# ...                ...              ...              ...
# 201              False             True            False
# 202              False             True            False
# 203              False             True            False
# 204               True            False            False
# 205              False             True            False
#
# [205 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 1 to 205
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   wheelbase              205 non-null    float64
#  1   carlength              205 non-null    float64
#  2   carwidth               205 non-null    float64
#  3   carheight              205 non-null    float64
#  4   curbweight             205 non-null    int64
#  5   enginesize             205 non-null    int64
#  6   boreratio              205 non-null    float64
#  7   stroke                 205 non-null    float64
#  8   compressionratio       205 non-null    float64
#  9   horsepower             205 non-null    int64
#  10  peakrpm                205 non-null    int64
#  11  citympg                205 non-null    int64
#  12  highwaympg             205 non-null    int64
#  13  price                  205 non-null    float64
#  14  symboling_-1           205 non-null    bool
#  15  symboling_0            205 non-null    bool
#  16  symboling_1            205 non-null    bool
#  17  symboling_2            205 non-null    bool
#  18  symboling_3            205 non-null    bool
#  19  fueltype_gas           205 non-null    bool
#  20  aspiration_turbo       205 non-null    bool
#  21  carbody_hardtop        205 non-null    bool
#  22  carbody_hatchback      205 non-null    bool
#  23  carbody_sedan          205 non-null    bool
#  24  drivewheel_fwd         205 non-null    bool
#  25  drivewheel_rwd         205 non-null    bool
#  26  enginetype_dohcv       205 non-null    bool
#  27  enginetype_ohc         205 non-null    bool
#  28  enginetype_ohcv        205 non-null    bool
#  29  cylindernumber_five    205 non-null    bool
#  30  cylindernumber_four    205 non-null    bool
#  31  cylindernumber_six     205 non-null    bool
#  32  cylindernumber_three   205 non-null    bool
#  33  cylindernumber_twelve  205 non-null    bool
#  34  fuelsystem_2bbl        205 non-null    bool
#  35  fuelsystem_idi         205 non-null    bool
#  36  fuelsystem_mpfi        205 non-null    bool
#  37  fuelsystem_spdi        205 non-null    bool
# dtypes: bool(24), float64(8), int64(6)
# memory usage: 28.8 KB

# %%
test_data = data.sample(n=25, random_state=42)
train_data = data.drop(test_data.index)

# train_data = data[0:180]
# test_data = data[180:]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180 entries, 1 to 205
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   wheelbase              180 non-null    float64
#  1   carlength              180 non-null    float64
#  2   carwidth               180 non-null    float64
#  3   carheight              180 non-null    float64
#  4   curbweight             180 non-null    int64
#  5   enginesize             180 non-null    int64
#  6   boreratio              180 non-null    float64
#  7   stroke                 180 non-null    float64
#  8   compressionratio       180 non-null    float64
#  9   horsepower             180 non-null    int64
#  10  peakrpm                180 non-null    int64
#  11  citympg                180 non-null    int64
#  12  highwaympg             180 non-null    int64
#  13  price                  180 non-null    float64
#  14  symboling_-1           180 non-null    bool
#  15  symboling_0            180 non-null    bool
#  16  symboling_1            180 non-null    bool
#  17  symboling_2            180 non-null    bool
#  18  symboling_3            180 non-null    bool
#  19  fueltype_gas           180 non-null    bool
#  20  aspiration_turbo       180 non-null    bool
#  21  carbody_hardtop        180 non-null    bool
#  22  carbody_hatchback      180 non-null    bool
#  23  carbody_sedan          180 non-null    bool
#  24  drivewheel_fwd         180 non-null    bool
#  25  drivewheel_rwd         180 non-null    bool
#  26  enginetype_dohcv       180 non-null    bool
#  27  enginetype_ohc         180 non-null    bool
#  28  enginetype_ohcv        180 non-null    bool
#  29  cylindernumber_five    180 non-null    bool
#  30  cylindernumber_four    180 non-null    bool
#  31  cylindernumber_six     180 non-null    bool
#  32  cylindernumber_three   180 non-null    bool
#  33  cylindernumber_twelve  180 non-null    bool
#  34  fuelsystem_2bbl        180 non-null    bool
#  35  fuelsystem_idi         180 non-null    bool
#  36  fuelsystem_mpfi        180 non-null    bool
#  37  fuelsystem_spdi        180 non-null    bool
# dtypes: bool(24), float64(8), int64(6)
# memory usage: 25.3 KB

# %% [markdown]
# # Visualization

# %%
train_data.head()
# Out:
#         wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# car_ID
# 1            88.6      168.8      64.1       48.8        2548         130
# 2            88.6      168.8      64.1       48.8        2548         130
# 3            94.5      171.2      65.5       52.4        2823         152
# 4            99.8      176.6      66.2       54.3        2337         109
# 5            99.4      176.6      66.4       54.3        2824         136
#
#         boreratio  stroke  compressionratio  horsepower  ...  enginetype_ohcv  \
# car_ID                                                   ...
# 1            3.47    2.68               9.0         111  ...            False
# 2            3.47    2.68               9.0         111  ...            False
# 3            2.68    3.47               9.0         154  ...             True
# 4            3.19    3.40              10.0         102  ...            False
# 5            3.19    3.40               8.0         115  ...            False
#
#         cylindernumber_five  cylindernumber_four  cylindernumber_six  \
# car_ID
# 1                     False                 True               False
# 2                     False                 True               False
# 3                     False                False                True
# 4                     False                 True               False
# 5                      True                False               False
#
#         cylindernumber_three  cylindernumber_twelve  fuelsystem_2bbl  \
# car_ID
# 1                      False                  False            False
# 2                      False                  False            False
# 3                      False                  False            False
# 4                      False                  False            False
# 5                      False                  False            False
#
#         fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi
# car_ID
# 1                False             True            False
# 2                False             True            False
# 3                False             True            False
# 4                False             True            False
# 5                False             True            False
#
# [5 rows x 38 columns]

# %%
train_corr = train_data[num_Cols].corr()
test_corr = test_data[num_Cols].corr()

# Set up the figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# Train Data Heatmap
sns.heatmap(train_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, ax=axes[0])
axes[0].set_title("Train Data Correlation Matrix")

# Test Data Heatmap
sns.heatmap(test_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, ax=axes[1])
axes[1].set_title("Test Data Correlation Matrix")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
def preprocess(X):
    X = X.drop(['carwidth', 'curbweight', 'highwaympg'], axis=1)
    return X

# %%
train_data = preprocess(train_data)
test_data = preprocess(test_data)

# %%
print(data.isna().nunique())
# Out:
# wheelbase                1
# carlength                1
# carwidth                 1
# carheight                1
# curbweight               1
# enginesize               1
# boreratio                1
# stroke                   1
# compressionratio         1
# horsepower               1
# peakrpm                  1
# citympg                  1
# highwaympg               1
# price                    1
# symboling_-1             1
# symboling_0              1
# symboling_1              1
# symboling_2              1
# symboling_3              1
# fueltype_gas             1
# aspiration_turbo         1
# carbody_hardtop          1
# carbody_hatchback        1
# carbody_sedan            1
# drivewheel_fwd           1
# drivewheel_rwd           1
# enginetype_dohcv         1
# enginetype_ohc           1
# enginetype_ohcv          1
# cylindernumber_five      1
# cylindernumber_four      1
# cylindernumber_six       1
# cylindernumber_three     1
# cylindernumber_twelve    1
# fuelsystem_2bbl          1
# fuelsystem_idi           1
# fuelsystem_mpfi          1
# fuelsystem_spdi          1
# dtype: int64

# %%
train_data
# Out:
#         wheelbase  carlength  carheight  enginesize  boreratio  stroke  \
# car_ID
# 1            88.6      168.8       48.8         130       3.47    2.68
# 2            88.6      168.8       48.8         130       3.47    2.68
# 3            94.5      171.2       52.4         152       2.68    3.47
# 4            99.8      176.6       54.3         109       3.19    3.40
# 5            99.4      176.6       54.3         136       3.19    3.40
# ...           ...        ...        ...         ...        ...     ...
# 201         109.1      188.8       55.5         141       3.78    3.15
# 202         109.1      188.8       55.5         141       3.78    3.15
# 203         109.1      188.8       55.5         173       3.58    2.87
# 204         109.1      188.8       55.5         145       3.01    3.40
# 205         109.1      188.8       55.5         141       3.78    3.15
#
#         compressionratio  horsepower  peakrpm  citympg  ...  enginetype_ohcv  \
# car_ID                                                  ...
# 1                    9.0         111     5000       21  ...            False
# 2                    9.0         111     5000       21  ...            False
# 3                    9.0         154     5000       19  ...             True
# 4                   10.0         102     5500       24  ...            False
# 5                    8.0         115     5500       18  ...            False
# ...                  ...         ...      ...      ...  ...              ...
# 201                  9.5         114     5400       23  ...            False
# 202                  8.7         160     5300       19  ...            False
# 203                  8.8         134     5500       18  ...             True
# 204                 23.0         106     4800       26  ...            False
# 205                  9.5         114     5400       19  ...            False
#
#         cylindernumber_five  cylindernumber_four  cylindernumber_six  \
# car_ID
# 1                     False                 True               False
# 2                     False                 True               False
# 3                     False                False                True
# 4                     False                 True               False
# 5                      True                False               False
# ...                     ...                  ...                 ...
# 201                   False                 True               False
# 202                   False                 True               False
# 203                   False                False                True
# 204                   False                False                True
# 205                   False                 True               False
#
#         cylindernumber_three  cylindernumber_twelve  fuelsystem_2bbl  \
# car_ID
# 1                      False                  False            False
# 2                      False                  False            False
# 3                      False                  False            False
# 4                      False                  False            False
# 5                      False                  False            False
# ...                      ...                    ...              ...
# 201                    False                  False            False
# 202                    False                  False            False
# 203                    False                  False            False
# 204                    False                  False            False
# 205                    False                  False            False
#
#         fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi
# car_ID
# 1                False             True            False
# 2                False             True            False
# 3                False             True            False
# 4                False             True            False
# 5                False             True            False
# ...                ...              ...              ...
# 201              False             True            False
# 202              False             True            False
# 203              False             True            False
# 204               True            False            False
# 205              False             True            False
#
# [180 rows x 35 columns]

# %% [markdown]
# # Training of the Model

# %%
X_train = train_data.drop(['price'], axis=1)
y_train = train_data['price'].values

X_test = test_data.drop(['price'], axis=1)
y_test = test_data['price'].values

# %% [markdown]
# The following normalizes the inputs of the model between 0 and 1

# %%
def zscore_normalize(X, mu=None, sigma=None):
    if mu is None:
        mu = np.mean(X, axis=0)
    if sigma is None:
        sigma = np.std(X, axis=0)
    X_norm = (X - mu) / (sigma + 1e-8)
    return X_norm, mu, sigma

# %%
# Normalize training data
X_train, mu, sigma = zscore_normalize(X_train)

# %%
# Normalize test data using training parameters
X_test, _, _ = zscore_normalize(X_test, mu, sigma)

# %% [markdown]
# Dealing with outliers

# %%
threshold = 4.5

# Identify outliers
outliers = np.where(np.abs(X_train) > threshold)

print("Indices of Outliers:")
print(outliers)

X_train = np.delete(X_train, outliers[0], axis=0)
y_train = np.delete(y_train, outliers[0], axis=0)

# Identify outliers
outliers_test = np.where(np.abs(X_test) > threshold)

print("Indices of Outliers:")
print(outliers_test)

X_test = np.delete(X_test, outliers_test[0], axis=0)
y_test = np.delete(y_test, outliers_test[0], axis=0)
# Out:
# Indices of Outliers:
# (array([  4,   5,   6,   7,   8,  44,  44,  60,  61,  61,  62,  65,  70,
#         71,  73,  74,  76,  77, 104, 109, 111, 112, 114, 114, 145, 146,
#        148]), array([25, 25, 25, 25, 25,  3, 29, 25, 17, 25, 25, 17, 33, 33, 33, 33, 33,
#        33, 33, 33, 17, 17,  7, 22, 17, 17, 17]))
# Indices of Outliers:
# (array([ 1,  4, 10, 16, 17, 22]), array([25, 25, 25, 28, 33, 17]))

# %%
print(X_test.shape)
print(X_train.shape)
# Out:
# (19, 34)
# (156, 34)

# %% [markdown]
# This code initializes values for a linear regression model

# %%
#seed helps in generating the same random values each time ensuring reproducibility in code
np.random.seed(42)   
weights = np.random.rand(X_train.shape[1]) # assigning weights to every input helps you find how much each input contributes to the ouptut
bias = 0.0 # gets updated during the training
learning_rate = 0.01 # determines how much weights change during training
num_iterations = 170 #specifies the number of iterations
reg_lambda= 500
m = len(y_train) # stores the number of training examples. Training example is a single data point from the training dataset which is used to teach the model

# %% [markdown]
# Gradient Descent code to train the linear regression model

# %%
# Gradient Descent with Loss Tracking
loss_history = []

for i in range(num_iterations): # runs for a pre-defined "num_iterations" times
    y_pred = np.dot(X_train, weights) + bias # calculates the predicted output for each training example
    error = y_pred - y_train # calculates the difference between the predicted values and the actual target

    mse_loss = np.mean(error ** 2)
    loss_history.append(mse_loss)
    
    weights_gradient = (2/m) * np.dot(X_train.T, error) +  (reg_lambda / m) * weights  # gradient tells us the direction and magnitude to adjust each weight to reduce the error.
    bias_gradient = (2/m) * np.sum(error) # tells how much to change the bais to improve predictions

    weights -= learning_rate * weights_gradient 
    bias -= learning_rate * bias_gradient   

    if i % 10 == 0:
        print(f"Iteration {i}: Loss = {mse_loss}, Weights Gradient = {np.linalg.norm(weights_gradient)}, Bias Gradient = {bias_gradient}")

y_train_pred = np.dot(X_train, weights) + bias
y_test_pred = np.dot(X_test, weights) + bias
# Out:
# Iteration 0: Loss = 200439080.19317833, Weights Gradient = 28087.605877883838, Bias Gradient = -24752.239448716948
# Iteration 10: Loss = 119917437.80788192, Weights Gradient = 7152.547582207692, Bias Gradient = -20061.938230693562
# Iteration 20: Loss = 82003202.39459325, Weights Gradient = 2981.998748124522, Bias Gradient = -16166.18672290192
# Iteration 30: Loss = 58865405.16353962, Weights Gradient = 1302.2210253708208, Bias Gradient = -13130.062007871476
# Iteration 40: Loss = 44055283.98869125, Weights Gradient = 978.5533857056299, Bias Gradient = -10755.586543116622
# Iteration 50: Loss = 34314731.80302381, Weights Gradient = 1210.3994261178, Bias Gradient = -8874.841427678508
# Iteration 60: Loss = 27773567.161128253, Weights Gradient = 1373.9773546125255, Bias Gradient = -7366.518310487941
# Iteration 70: Loss = 23304755.407494903, Weights Gradient = 1416.1476992933103, Bias Gradient = -6143.826504810648
# Iteration 80: Loss = 20207096.608340137, Weights Gradient = 1374.5651893740528, Bias Gradient = -5143.7487300083
# Iteration 90: Loss = 18033096.430481374, Weights Gradient = 1284.433815994095, Bias Gradient = -4319.677078236953
# Iteration 100: Loss = 16490918.084211845, Weights Gradient = 1170.2352209015178, Bias Gradient = -3636.508760799482
# Iteration 110: Loss = 15386634.672977313, Weights Gradient = 1047.6503613934751, Bias Gradient = -3067.3534185175295
# Iteration 120: Loss = 14589271.670772014, Weights Gradient = 926.2040822362624, Bias Gradient = -2591.2892932574164
# Iteration 130: Loss = 14009125.060191503, Weights Gradient = 811.3349585955956, Bias Gradient = -2191.8095380974287
# Iteration 140: Loss = 13584014.404553153, Weights Gradient = 705.8476773365757, Bias Gradient = -1855.7288988496905
# Iteration 150: Loss = 13270391.48785669, Weights Gradient = 610.893000154021, Bias Gradient = -1572.4017646045543
# Iteration 160: Loss = 13037485.619418982, Weights Gradient = 526.615726354943, Bias Gradient = -1333.1537135841363

# %%
print("Actual prices:", y_test[:10])
print("Predicted prices:", y_test_pred[:10])
# Out:
# Actual prices: [30760.  9549. 11850.  7799.  7788.  9258. 10198.  7775.  8238. 18280.]
# Predicted prices: [22216.51311438 10040.36960161 12824.44688647  6473.48764135
#   7952.79894426  8404.56867859 11136.72172307  8156.3083214
#   8743.63790471 16047.0756    ]

# %%
# Calculate residuals
residuals_train = y_train - y_train_pred
residuals_test = y_test - y_test_pred

# Set up the figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# Train Data Heatmap
sns.histplot(residuals_train, kde=True, ax=axes[0])
axes[0].set_title("Train Data Correlation Matrix")

# Test Data Heatmap
sns.histplot(residuals_test, kde=True, ax=axes[1])
axes[1].set_title("Test Data Correlation Matrix")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))  # Two side-by-side plots

# Train Residual Plot
sns.scatterplot(x=y_train_pred, y=residuals_train, alpha=0.5, color="blue", ax=axes[0])
axes[0].axhline(y=0, color='black', linestyle='--', linewidth=1)  # Zero Residual Line
axes[0].set_xlabel("Predicted Values (Train)")
axes[0].set_ylabel("Residuals (Errors)")
axes[0].set_title("Train Residuals vs. Predicted Values")
axes[0].grid(True)

# Test Residual Plot
sns.scatterplot(x=y_test_pred, y=residuals_test, alpha=0.5, color="red", ax=axes[1])
axes[1].axhline(y=0, color='black', linestyle='--', linewidth=1)  # Zero Residual Line
axes[1].set_xlabel("Predicted Values (Test)")
axes[1].set_ylabel("Residuals (Errors)")
axes[1].set_title("Test Residuals vs. Predicted Values")
axes[1].grid(True)

plt.tight_layout()  # Adjust layout
plt.show()

# %%
# Plotting the Loss vs. Epochs
plt.figure(figsize=(8, 6))
plt.plot(range(num_iterations), loss_history, color="b", label="Loss")
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error (MSE)")
plt.title("Loss vs. Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))

# Scatter plot of the actual price vs the pedicted price
plt.scatter(y_train, y_train_pred, color = 'orange')

# Line plot of the best-fit line (model predictions)
plt.plot([min(y_train), max(y_train)], [min(y_train_pred), max(y_train_pred)], 'k:')

# Add labels and title
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Predicted vs Actual prices')
plt.show()

# %%
total_train = np.sum((y_train - y_train.mean()) ** 2)
residual_train = np.sum((y_train - y_train_pred) ** 2)
r2_train = 1-(residual_train / total_train)

residual_test = np.sum((y_test - y_test_pred) ** 2)
total_test = np.sum((y_test - y_test.mean()) ** 2)
r2_test = 1-(residual_test / total_test)

# %%
print("R-squared (R²) for Train set:", r2_train)
print("R-squared (R²) for Test set:", r2_test)
# Out:
# R-squared (R²) for Train set: 0.7279543959768309
# R-squared (R²) for Test set: 0.7459438004807496

# %%
print(f"Price ranges from {y_test.min()} to {y_test.max()}")

mae = np.mean(np.abs(y_test - y_test_pred))
rmse = np.sqrt(np.mean((y_test - y_test_pred) ** 2))
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Price ranges from 6479.0 to 40960.0
# Mean Absolute Error (MAE): 2425.256665831421
# Root Mean Squared Error (RMSE): 4387.420178713399
